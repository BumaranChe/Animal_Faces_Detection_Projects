# %% [markdown]
# <a href="https://colab.research.google.com/github/BumaranChe/Animal_Faces_Detection_Projects/blob/main/Pre_Trained(YOLOv5)_(GitHub).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1.0 Install Yolov5

# %%
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# !pip install -r requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17521, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 17521 (delta 9), reused 0 (delta 0), pack-reused 17497 (from 4)
# Receiving objects: 100% (17521/17521), 16.61 MiB | 18.73 MiB/s, done.
# Resolving deltas: 100% (11998/11998), done.
# /content/yolov5
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 111.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 88.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 59.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.8 MB/s eta 0:00:00
# ...

# %% [markdown]
# # 2.0 Use detect.py (pre-trained) to detect animal faces

# %%
# !python detect.py --weights yolov5s.pt --img 352 --conf 0.25 --source /content/Pre_Trained_YOLO      # Path to images or folder, video, webcam
# Out:
# detect: weights=['yolov5s.pt'], source=/content/Pre_Trained_YOLO, data=data/coco128.yaml, imgsz=[352, 352], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-423-g567c6646 Python-3.11.13 torch-2.6.0+cu124 CPU
#
# ...
# 100% 14.1M/14.1M [00:00<00:00, 63.6MB/s]
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# image 1/20 /content/Pre_Trained_YOLO/pos1.jpg: 352x352 1 dog, 1 chair, 253.3ms
# image 2/20 /content/Pre_Trained_YOLO/pos10.jpg: 352x352 1 bear, 216.7ms
# image 3/20 /content/Pre_Trained_YOLO/pos11.jpg: 352x352 1 dog, 138.6ms
# ...

# %%
from IPython.display import Image
Image(filename='runs/detect/exp/pos1.jpg')

# %%
from IPython.display import Image
Image(filename='runs/detect/exp/pos2.jpg')

# %%
from IPython.display import Image
Image(filename='runs/detect/exp/pos3.jpg')

# %%
from IPython.display import Image
Image(filename='runs/detect/exp/pos4.jpg')

# %% [markdown]
# This pre-trained model not focusing on detecting animal faces but it detects the whole animal image and gives the results. This pre-trained model is not perfect because it detects pos4.jpg ( a tiger) as zebra. But it detects pos1.jpg (a dog) and pos3.jpg (a zebra) accurately.
