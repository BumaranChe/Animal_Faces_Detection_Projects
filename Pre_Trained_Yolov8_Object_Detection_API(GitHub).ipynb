# %% [markdown]
# <a href="https://colab.research.google.com/github/BumaranChe/Animal_Faces_Detection_Projects/blob/main/Pre_Trained_Yolov8_Object_Detection_API(GitHub).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Using YOLOv8 pre-trained with Detection Api**

# %% [markdown]
# # 1.0 Install ultralytics package

# %%
pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 16.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 67.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 59.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 46.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 15.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 6.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 86.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# # 2.0 Load yolov8 pre-trained model and load image

# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt
import cv2

# Load YOLOv8 pre-trained model
model = YOLO("yolov8n.pt")

# Run detection on an image
results = model("pos1.jpg")

# Get annotated image
annotated_image = results[0].plot()  # returns numpy array (BGR)

# Convert BGR to RGB for matplotlib
annotated_image = cv2.cvtColor(annotated_image, cv2.COLOR_BGR2RGB)

# Display inline
plt.figure(figsize=(10, 8))
plt.imshow(annotated_image)
plt.axis("off")
plt.show()
# Out:
# image 1/1 /content/pos1.jpg: 640x640 1 bench, 1 dog, 326.2ms
# Speed: 8.7ms preprocess, 326.2ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 640)

# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt
import cv2

# Load YOLOv8 pre-trained model
model = YOLO("yolov8n.pt")

# Run detection on an image
results = model("pos15.jpg")

# Get annotated image
annotated_image = results[0].plot()  # returns numpy array (BGR)

# Convert BGR to RGB for matplotlib
annotated_image = cv2.cvtColor(annotated_image, cv2.COLOR_BGR2RGB)

# Display inline
plt.figure(figsize=(10, 8))
plt.imshow(annotated_image)
plt.axis("off")
plt.show()
# Out:
# image 1/1 /content/pos15.jpg: 640x640 1 bear, 258.8ms
# Speed: 6.9ms preprocess, 258.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)

# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt
import cv2

# Load YOLOv8 pre-trained model
model = YOLO("yolov8n.pt")

# Run detection on an image
results = model("pos2.jpg")

# Get annotated image
annotated_image = results[0].plot()  # returns numpy array (BGR)

# Convert BGR to RGB for matplotlib
annotated_image = cv2.cvtColor(annotated_image, cv2.COLOR_BGR2RGB)

# Display inline
plt.figure(figsize=(10, 8))
plt.imshow(annotated_image)
plt.axis("off")
plt.show()
# Out:
# image 1/1 /content/pos2.jpg: 640x640 1 bottle, 2 bowls, 1 chair, 2 potted plants, 1 bed, 338.0ms
# Speed: 8.3ms preprocess, 338.0ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 640)

# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt
import cv2

# Load YOLOv8 pre-trained model
model = YOLO("yolov8n.pt")

# Run detection on an image
results = model("pos18.jpg")

# Get annotated image
annotated_image = results[0].plot()  # returns numpy array (BGR)

# Convert BGR to RGB for matplotlib
annotated_image = cv2.cvtColor(annotated_image, cv2.COLOR_BGR2RGB)

# Display inline
plt.figure(figsize=(10, 8))
plt.imshow(annotated_image)
plt.axis("off")
plt.show()
# Out:
# image 1/1 /content/pos18.jpg: 640x640 1 giraffe, 297.1ms
# Speed: 6.8ms preprocess, 297.1ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 640)

# %% [markdown]
# Based on this pre-trained model results, it detects pos1.jpg (a dog) and post15.jpg (a bear). However, it unable to detect pos2.jpg (fake frog image). It also detects post18.jpg (a koala) as a giraffe. It's not consistent because it only able to detect few animals. Pre-trained model using COCO dataset and only able to detect dog, cat, horse, sheep, cow, elephant, bear, zebra, giraffe and bird. This model checks whole image for animal detection, it does not only focus on animal faces.
